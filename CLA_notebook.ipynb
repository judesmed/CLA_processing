# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
meta_data = pd.read_csv('data/CLA_meta_from_2018.csv')
joint_committees = pd.read_excel('data/Joint_Committees.xlsx', index_col=0)

# %%
meta_data.head(3)
# Out:
#    deposit_number  jc_number                                     jc_name_fr  \
# 0          175235      100.0  commission paritaire auxiliaire pour ouvriers
# 1          170873      100.0  commission paritaire auxiliaire pour ouvriers
# 2          172225      100.0  commission paritaire auxiliaire pour ouvriers
#
#                                       jc_name_nl  \
# 0  aanvullend paritair comite voor de werklieden
# 1  aanvullend paritair comite voor de werklieden
# 2  aanvullend paritair comite voor de werklieden
#
#                                         cla_title_fr  \
# 0                            Salaire horaire minimum
# 1       Accord sectoriel 2021-2022 - pouvoir dachat
# 2  Dispense de l'obligation de disponibilité adap...
#
#                                         cla_title_nl retrieve_date label  \
# 0                                     Minimumuurloon    2022-12-07   new
# 1           Sectoraal akkoord 2021-2022 - koopkracht    2022-12-07   new
# ...

# %% [markdown]
# meta_data.csv contains fr and nl

# %%
# Out:
# 2022-12-14 11:47:59.095952: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-14 11:47:59.382422: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-14 11:47:59.382522: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
# Classification of layout
# import tensorflow as tf
# # Define the CNN model
# model = tf.keras.models.Sequential([
#     tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(64, 64, 1)),
#     tf.keras.layers.MaxPooling2D((2, 2)),
#     tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
#     tf.keras.layers.MaxPooling2D((2, 2)),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.Dense(4, activation='softmax')
# ])

# # Compile the model
# model.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])

# # Train the model on a dataset of PDF documents with known layout types
# model.fit(pdf_docs, pdf_labels, epochs=10)

# # Use the model to classify the layout of a new PDF document
# predictions = model.predict(new_pdf)

# %%
# import findspark package
import findspark
# determine spark directory 
findspark.init("/Users/julienugent/spark")
# import pyspark
import pyspark
# initialize spark context
sc = pyspark.SparkContext()
# initialize spark session
spark = pyspark.sql.SparkSession(sc)
